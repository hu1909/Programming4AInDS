# %% [markdown]
# #1 Numbers in Python

# %% [markdown]
# ##1.1 Samples for integer
# The following example shows how to write an ***integer*** in Python.
#
# Notes:
# * ***type(.)***: return the variable's data type
# * ***isinstance(variable,data-type)***: verify if the *variable* is an instance of the *data-type*
# * ***str(.)***: convert to string type

# %%
x = 10
print("x = {}".format(x))
print("Type of x: {}".format(str(type(x))))
print("x is an instance of int: {}".format(isinstance(x, int)))
print("x is an instance of float: {}".format(isinstance(x, float)))
print("x is an instance of float: {}".format(isinstance(x, complex)))
# Out:
# x = 10
# Type of x: <class 'int'>
# x is an instance of int: True
# x is an instance of float: False
# x is an instance of float: False

# %% [markdown]
# ##1.2 Exercises

# %% [markdown]
# ###1.2.1 Floating

# %%
"""
Fill your code to this cell to show the output as the cell followed
"""
#YOUR CODE IS HERE
# Out:
# '\nFill your code to this cell to show the output as the cell followed\n'

# %%
"""
Fill your code to this cell to show the output as the cell followed
"""
#YOUR CODE IS HERE
# Out:
# x = 10.5
# Type of x: <class 'float'>
# x is an instance of int: False
# x is an instance of float: True
# x is an instance of float: False

# %% [markdown]
# ###1.2.2 Complex

# %%
"""
Fill your code to this cell to show the output as the cell followed
"""
#YOUR CODE IS HERE
# Out:
# x = (1.5+2j)
# Type of x: <class 'complex'>
# x is an instance of int: False
# x is an instance of float: False
# x is an instance of float: True

# %% [markdown]
# #2 String in Python

# %% [markdown]
# ##2.1 Samples

# %% [markdown]
# ###2.1.1 How to write a string

# %%
s1 = 'Programming foundation for data analytics and visualization'
s2 = "Programming foundation for data analytics and visualization"
s3 = """
    Course: Programming foundation for data analytics and visualization
    Field: Data Science
    """
print("Single-line string: ", s1)
print("Single-line string: ", s2)
print("Multi-lines string: ", s3)
# Out:
# Single-line string:  Programming foundation for data analytics and visualization
# Single-line string:  Programming foundation for data analytics and visualization
# Multi-lines string:
#     Course: Programming foundation for data analytics and visualization
#     Field: Data Science

# %% [markdown]
# ###2.1.2 String formatted

# %%
a, b = 10.5, 20.25
s = f'a = {a}, b = {b}'
print(s)
# Out:
# a = 10.5, b = 20.25

# %%
a, b = 10.5, 20.25
s = 'a = {0}, b = {1}'.format(a,b) # a is at 0, b is at 1 in the parameter list
print(s)
# Out:
# a = 10.5, b = 20.25

# %%
a, b = 10.5, 20.25
s1 = 'a = {:5.2f}\nb = {:10.4f}\n'.format(a,b)
s2 = 'a = {:5.2f}\nb = {:<15.4f}\n'.format(a,b) # <: left-alignment
s3 = 'a = {:5.2f}\nb = {:>15.4f}\n'.format(a,b) # >: right-alignment
s4 = 'a = {:5.2f}\nb = {:^15.4f}\n'.format(a,b) # ^: center-alignment
s5 = 'a = {:5.2f}\nb = {:015.4f}\n'.format(a,b) # 0 in 015.4f => preceeding with 0
s6 = 'b = {1:5.2f}\na = {0:015.4f}\n'.format(a,b) # 0 in 015.4f => preceeding with 0
print(s1)
print(s2)
print(s3)
print(s4)
print(s5)
print(s6)
# Out:
# a = 10.50
# b =    20.2500
#
# a = 10.50
# b = 20.2500
#
# a = 10.50
# b =         20.2500
#
# a = 10.50
# b =     20.2500
#
# a = 10.50
# b = 0000000020.2500
#
# b = 20.25
# a = 0000000010.5000

# %% [markdown]
# ###2.1.3 String formatted with dynamic width and precision

# %%
a, b = 10.5, 20.1
line = 'a = {:0{w1}.{p1}f}; b={:0{w2}.{p2}f}'.format(a, b, w1=10, p1=2, w2=15, p2=5)
print(line)
# Out:
# a = 0000010.50; b=000000020.10000

# %% [markdown]
# ###2.1.4 String repeated

# %%
s1 = '#'*4 # repeat character # 4 times 
s2 = '-'*10 # repeat character - 10 times 
print(s1)
print(s2)
# Out:
# ####
# ----------

# %% [markdown]
# ##2.2 Exercises

# %%
"""
Fill your code to this cell to show the output as the cell followed
"""
w, b = 2, 10
x = 5

# YOUR CODE IS HERE
# Out:
# w = 2; b = 10
# x = 5
# w*x + b = 2*5 + 10 = 20.00

# %%
"""
Fill your code to this cell to show the output as the cell followed.
Each column: width = 20 characters
"""

#YOUR CODE IS HERE
# Out:
# -------------------------------------------
# |      Variable      |       Value        |
# -------------------------------------------

# %% [markdown]
# #3 Expressions
# * References:
#   * [Math library in Python](https://www.w3schools.com/python/module_math.asp)

# %% [markdown]
# ##3.1 Samples

# %%
import math
v = input("Enter a number: ")
print('type of v is: ', type(v))
v = float(v) # casting to float
print(f'after converting v to float, v = {v}')
print('e^v = e^({0}) = {1:<10.3f}'.format(v, math.exp(v)))
# Out:
# Enter a number: 10
# type of v is:  <class 'str'>
# after converting v to float, v = 10.0
# e^v = e^(10.0) = 22026.466

# %% [markdown]
# ##3.2 Exercises

# %%
"""
Fill your code to this cell to show the output as the cell followed.
Each column: width = 20 characters
"""

#YOUR CODE IS HERE
# Out:
# -------------------------------------------
# |      Variable      |       Value        |
# -------------------------------------------
# |         x          |        3.00        |
# |         y          |       -3.00        |
# |         z          |        5.00        |
# -------------------------------------------

# %%
"""
Fill your code to this cell to show the output as the cell followed.
Each column: width = 15 characters
"""

#YOUR CODE IS HERE
# Out:
# -----------------------------------------------------------------
# |  Variable(v)  |     Value     |      e^v      |    sqrt(v)    |
# -----------------------------------------------------------------
# |       x       |     3.00      |     20.09     |     1.73      |
# |       y       |     -3.00     |     0.05      |   undefined   |
# |       z       |     5.00      |    148.41     |     2.24      |
# -----------------------------------------------------------------
